# %% [markdown]
# # Basic Tabular Mining Tips
#
# ---
# In this short tutorial, we demontrate how to perform a simple data mining task on the "Kicked!" dataset.
#
# We will be covering:
#
#
#
# 1.   Data Preprocessing using Pandas.
# 2.   Some basic ideas in feature engineering.
# 3.   Basic parameter tuning for tree models.

# %%
# !pip install lightgbm xgboost catboost category-encoders sklearn pandas==1.1.5

# %%
# !pip install hyperopt
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: hyperopt in c:\programdata\anaconda3\lib\site-packages (0.2.5)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from hyperopt) (1.3.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from hyperopt) (4.42.1)
# Requirement already satisfied: future in c:\programdata\anaconda3\lib\site-packages (from hyperopt) (0.18.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from hyperopt) (1.16.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from hyperopt) (1.2.1)
# Requirement already satisfied: networkx>=2.2 in c:\programdata\anaconda3\lib\site-packages (from hyperopt) (2.4)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from hyperopt) (1.14.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from networkx>=2.2->hyperopt) (4.4.1)

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('./final/train_final.csv', engine='python')
test = pd.read_csv('./final/test_final.csv', engine='python')

x_train = train.drop('loan_status', axis=1)
x_test = test.drop('loan_status', axis=1)

y_train = train['loan_status']
y_test = test['loan_status']

# %%
TRAIN_IDX = x_train.shape[0]
TEST_IDX = TRAIN_IDX + x_test.shape[0]

# %%
x = pd.concat([x_train, x_test], axis=0)
y = pd.concat([y_train, y_test], axis=0)

data = pd.concat([x, y], axis=1)

# %%
data.columns.to_list()
# Out:
# ['continuous_annual_inc',
#  'continuous_annual_inc_joint',
#  'continuous_delinq_2yrs',
#  'continuous_dti',
#  'continuous_dti_joint',
#  'continuous_fico_range_high',
#  'continuous_fico_range_low',
#  'continuous_funded_amnt',
#  'continuous_funded_amnt_inv',
#  'continuous_inq_last_6mths',
#  'continuous_installment',
#  'continuous_int_rate',
#  'continuous_last_fico_range_high',
#  'continuous_last_fico_range_low',
#  'continuous_loan_amnt',
#  'continuous_mths_since_last_delinq',
#  'continuous_mths_since_last_major_derog',
#  'continuous_mths_since_last_record',
#  'continuous_open_acc',
#  'continuous_pub_rec',
#  'discrete_addr_state_1_one_hot',
#  'discrete_addr_state_2_one_hot',
#  'discrete_addr_state_3_one_hot',
#  'discrete_addr_state_4_one_hot',
#  'discrete_addr_state_5_one_hot',
#  'discrete_addr_state_6_one_hot',
#  'discrete_addr_state_7_one_hot',
#  'discrete_addr_state_8_one_hot',
#  'discrete_addr_state_9_one_hot',
#  'discrete_addr_state_10_one_hot',
#  'discrete_addr_state_11_one_hot',
#  'discrete_addr_state_12_one_hot',
#  'discrete_addr_state_13_one_hot',
#  'discrete_addr_state_14_one_hot',
#  'discrete_addr_state_15_one_hot',
#  'discrete_addr_state_16_one_hot',
#  'discrete_addr_state_17_one_hot',
#  'discrete_addr_state_18_one_hot',
#  'discrete_addr_state_19_one_hot',
#  'discrete_addr_state_20_one_hot',
#  'discrete_addr_state_21_one_hot',
#  'discrete_addr_state_22_one_hot',
#  'discrete_addr_state_23_one_hot',
#  'discrete_addr_state_24_one_hot',
#  'discrete_addr_state_25_one_hot',
#  'discrete_addr_state_26_one_hot',
#  'discrete_addr_state_27_one_hot',
#  'discrete_addr_state_28_one_hot',
#  'discrete_addr_state_29_one_hot',
#  'discrete_addr_state_30_one_hot',
#  'discrete_addr_state_31_one_hot',
#  'discrete_addr_state_32_one_hot',
#  'discrete_addr_state_33_one_hot',
#  'discrete_addr_state_34_one_hot',
#  'discrete_addr_state_35_one_hot',
#  'discrete_addr_state_36_one_hot',
#  'discrete_addr_state_37_one_hot',
#  'discrete_addr_state_38_one_hot',
#  'discrete_addr_state_39_one_hot',
#  'discrete_addr_state_40_one_hot',
#  'discrete_addr_state_41_one_hot',
#  'discrete_addr_state_42_one_hot',
#  'discrete_addr_state_43_one_hot',
#  'discrete_addr_state_44_one_hot',
#  'discrete_addr_state_45_one_hot',
#  'discrete_addr_state_46_one_hot',
#  'discrete_addr_state_47_one_hot',
#  'discrete_addr_state_48_one_hot',
#  'discrete_addr_state_49_one_hot',
#  'discrete_application_type_1_one_hot',
#  'discrete_application_type_2_one_hot',
#  'discrete_emp_length_1_one_hot',
#  'discrete_emp_length_2_one_hot',
#  'discrete_emp_length_3_one_hot',
#  'discrete_emp_length_4_one_hot',
#  'discrete_emp_length_5_one_hot',
#  'discrete_emp_length_6_one_hot',
#  'discrete_emp_length_7_one_hot',
#  'discrete_emp_length_8_one_hot',
#  'discrete_emp_length_9_one_hot',
#  'discrete_emp_length_10_one_hot',
#  'discrete_emp_length_11_one_hot',
#  'discrete_emp_length_12_one_hot',
#  'discrete_grade_1_one_hot',
#  'discrete_grade_2_one_hot',
#  'discrete_grade_3_one_hot',
#  'discrete_grade_4_one_hot',
#  'discrete_grade_5_one_hot',
#  'discrete_grade_6_one_hot',
#  'discrete_grade_7_one_hot',
#  'discrete_home_ownership_1_one_hot',
#  'discrete_home_ownership_2_one_hot',
#  'discrete_home_ownership_3_one_hot',
#  'discrete_home_ownership_4_one_hot',
#  'discrete_policy_code_1_one_hot',
#  'discrete_purpose_1_one_hot',
#  'discrete_purpose_2_one_hot',
#  'discrete_purpose_3_one_hot',
#  'discrete_purpose_4_one_hot',
#  'discrete_purpose_5_one_hot',
#  'discrete_purpose_6_one_hot',
#  'discrete_purpose_7_one_hot',
#  'discrete_purpose_8_one_hot',
#  'discrete_purpose_9_one_hot',
#  'discrete_purpose_10_one_hot',
#  'discrete_purpose_11_one_hot',
#  'discrete_purpose_12_one_hot',
#  'discrete_pymnt_plan_1_one_hot',
#  'discrete_sub_grade_1_one_hot',
#  'discrete_sub_grade_2_one_hot',
#  'discrete_sub_grade_3_one_hot',
#  'discrete_sub_grade_4_one_hot',
#  'discrete_sub_grade_5_one_hot',
#  'discrete_sub_grade_6_one_hot',
#  'discrete_sub_grade_7_one_hot',
#  'discrete_sub_grade_8_one_hot',
#  'discrete_sub_grade_9_one_hot',
#  'discrete_sub_grade_10_one_hot',
#  'discrete_sub_grade_11_one_hot',
#  'discrete_sub_grade_12_one_hot',
#  'discrete_sub_grade_13_one_hot',
#  'discrete_sub_grade_14_one_hot',
#  'discrete_sub_grade_15_one_hot',
#  'discrete_sub_grade_16_one_hot',
#  'discrete_sub_grade_17_one_hot',
#  'discrete_sub_grade_18_one_hot',
#  'discrete_sub_grade_19_one_hot',
#  'discrete_sub_grade_20_one_hot',
#  'discrete_sub_grade_21_one_hot',
#  'discrete_sub_grade_22_one_hot',
#  'discrete_sub_grade_23_one_hot',
#  'discrete_sub_grade_24_one_hot',
#  'discrete_sub_grade_25_one_hot',
#  'discrete_sub_grade_26_one_hot',
#  'discrete_sub_grade_27_one_hot',
#  'discrete_sub_grade_28_one_hot',
#  'discrete_sub_grade_29_one_hot',
#  'discrete_sub_grade_30_one_hot',
#  'discrete_sub_grade_31_one_hot',
#  'discrete_sub_grade_32_one_hot',
#  'discrete_sub_grade_33_one_hot',
#  'discrete_sub_grade_34_one_hot',
#  'discrete_sub_grade_35_one_hot',
#  'discrete_term_1_one_hot',
#  'discrete_term_2_one_hot',
#  'loan_status']

# %% [markdown]
# ## Basic Data Manipulation
#
# Let us see how we can do some basic data preprocessing

# %%
data['loan_status'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data['loan_status'].value_counts()
# Out:
# 1    80014
# 0    19986
# Name: loan_status, dtype: int64

# %% [markdown]
# ## TreeBased Models
#
# ---
# In this example, we use lightgbm as the tree model of choice.

# %%
train = data.iloc[:TRAIN_IDX, :]
test = data.iloc[TRAIN_IDX:TEST_IDX, :]

# %%
import lightgbm as lgb
train_dataset = lgb.Dataset(train.drop(columns='loan_status'), train['loan_status'])
test_dataset = lgb.Dataset(test.drop(columns='loan_status'), test['loan_status'])

# %%
param = {'num_leaves': 31, 'objective': 'binary', 'metric':'binary_error'}
num_round = 2000

# %%
model = lgb.train(param, train_dataset, num_boost_round=num_round, valid_sets=[train_dataset, test_dataset])
# Out:
# [LightGBM] [Info] Number of positive: 20672, number of negative: 29328
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2607
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 141
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.413440 -> initscore=-0.349763
# [LightGBM] [Info] Start training from score -0.349763
# [1]	training's binary_error: 0.41344	valid_1's binary_error: 0.39348
# [2]	training's binary_error: 0.41344	valid_1's binary_error: 0.39348
# [3]	training's binary_error: 0.41	valid_1's binary_error: 0.39074
# [4]	training's binary_error: 0.39362	valid_1's binary_error: 0.37906
# [5]	training's binary_error: 0.38106	valid_1's binary_error: 0.36738
# [6]	training's binary_error: 0.37056	valid_1's binary_error: 0.3612
# [7]	training's binary_error: 0.363	valid_1's binary_error: 0.3561
# [8]	training's binary_error: 0.3588	valid_1's binary_error: 0.35232
# [9]	training's binary_error: 0.35488	valid_1's binary_error: 0.35072
# [10]	training's binary_error: 0.35082	valid_1's binary_error: 0.34896
# [11]	training's binary_error: 0.34738	valid_1's binary_error: 0.34706
# [12]	training's binary_error: 0.34476	valid_1's binary_error: 0.34616
# [13]	training's binary_error: 0.34272	valid_1's binary_error: 0.3458
# [14]	training's binary_error: 0.34148	valid_1's binary_error: 0.3454
# [15]	training's binary_error: 0.34096	valid_1's binary_error: 0.3446
# [16]	training's binary_error: 0.3399	valid_1's binary_error: 0.34352
# [17]	training's binary_error: 0.3391	valid_1's binary_error: 0.34296
# [18]	training's binary_error: 0.338	valid_1's binary_error: 0.343
# [19]	training's binary_error: 0.337	valid_1's binary_error: 0.34298
# [20]	training's binary_error: 0.33584	valid_1's binary_error: 0.34258
# [21]	training's binary_error: 0.33478	valid_1's binary_error: 0.3419
# [22]	training's binary_error: 0.3332	valid_1's binary_error: 0.34144
# [23]	training's binary_error: 0.33208	valid_1's binary_error: 0.3419
# [24]	training's binary_error: 0.33144	valid_1's binary_error: 0.34116
# [25]	training's binary_error: 0.33096	valid_1's binary_error: 0.34102
# [26]	training's binary_error: 0.3302	valid_1's binary_error: 0.3407
# [27]	training's binary_error: 0.32938	valid_1's binary_error: 0.3397
# [28]	training's binary_error: 0.32888	valid_1's binary_error: 0.33978
# [29]	training's binary_error: 0.32854	valid_1's binary_error: 0.33972
# [30]	training's binary_error: 0.3282	valid_1's binary_error: 0.33998
# [31]	training's binary_error: 0.32776	valid_1's binary_error: 0.33974
# [32]	training's binary_error: 0.3268	valid_1's binary_error: 0.3395
# [33]	training's binary_error: 0.32596	valid_1's binary_error: 0.33976
# [34]	training's binary_error: 0.32542	valid_1's binary_error: 0.33936
# [35]	training's binary_error: 0.3248	valid_1's binary_error: 0.33894
# [36]	training's binary_error: 0.3244	valid_1's binary_error: 0.33848
# [37]	training's binary_error: 0.32368	valid_1's binary_error: 0.33886
# [38]	training's binary_error: 0.32334	valid_1's binary_error: 0.33892
# [39]	training's binary_error: 0.32294	valid_1's binary_error: 0.33844
# [40]	training's binary_error: 0.3221	valid_1's binary_error: 0.33864
# [41]	training's binary_error: 0.32194	valid_1's binary_error: 0.33874
# [42]	training's binary_error: 0.32194	valid_1's binary_error: 0.33856
# [43]	training's binary_error: 0.32028	valid_1's binary_error: 0.33854
# [44]	training's binary_error: 0.3203	valid_1's binary_error: 0.33872
# [45]	training's binary_error: 0.31976	valid_1's binary_error: 0.339
# [46]	training's binary_error: 0.31948	valid_1's binary_error: 0.33896
# [47]	training's binary_error: 0.31896	valid_1's binary_error: 0.33924
# [48]	training's binary_error: 0.31846	valid_1's binary_error: 0.33928
# [49]	training's binary_error: 0.3184	valid_1's binary_error: 0.33932
# [50]	training's binary_error: 0.31716	valid_1's binary_error: 0.33924
# [51]	training's binary_error: 0.31722	valid_1's binary_error: 0.33938
# [52]	training's binary_error: 0.31716	valid_1's binary_error: 0.33884
# [53]	training's binary_error: 0.31618	valid_1's binary_error: 0.3383
# [54]	training's binary_error: 0.31594	valid_1's binary_error: 0.33822
# [55]	training's binary_error: 0.31558	valid_1's binary_error: 0.33846
# [56]	training's binary_error: 0.3156	valid_1's binary_error: 0.33854
# [57]	training's binary_error: 0.31522	valid_1's binary_error: 0.33874
# [58]	training's binary_error: 0.31502	valid_1's binary_error: 0.33876
# [59]	training's binary_error: 0.31456	valid_1's binary_error: 0.33884
# [60]	training's binary_error: 0.31412	valid_1's binary_error: 0.3386
# [61]	training's binary_error: 0.31352	valid_1's binary_error: 0.33812
# [62]	training's binary_error: 0.31324	valid_1's binary_error: 0.33826
# [63]	training's binary_error: 0.31274	valid_1's binary_error: 0.3378
# [64]	training's binary_error: 0.3125	valid_1's binary_error: 0.338
# [65]	training's binary_error: 0.31226	valid_1's binary_error: 0.33802
# [66]	training's binary_error: 0.3119	valid_1's binary_error: 0.33844
# [67]	training's binary_error: 0.3113	valid_1's binary_error: 0.33864
# [68]	training's binary_error: 0.31074	valid_1's binary_error: 0.33868
# [69]	training's binary_error: 0.31028	valid_1's binary_error: 0.33854
# [70]	training's binary_error: 0.30998	valid_1's binary_error: 0.33844
# [71]	training's binary_error: 0.31	valid_1's binary_error: 0.3387
# [72]	training's binary_error: 0.30948	valid_1's binary_error: 0.3386
# [73]	training's binary_error: 0.30932	valid_1's binary_error: 0.33884
# [74]	training's binary_error: 0.3093	valid_1's binary_error: 0.33876
# [75]	training's binary_error: 0.30912	valid_1's binary_error: 0.33878
# [76]	training's binary_error: 0.3087	valid_1's binary_error: 0.33894
# [77]	training's binary_error: 0.30846	valid_1's binary_error: 0.33896
# [78]	training's binary_error: 0.30786	valid_1's binary_error: 0.33902
# [79]	training's binary_error: 0.30754	valid_1's binary_error: 0.33892
# [80]	training's binary_error: 0.30724	valid_1's binary_error: 0.33892
# [81]	training's binary_error: 0.30684	valid_1's binary_error: 0.3389
# [82]	training's binary_error: 0.30634	valid_1's binary_error: 0.33882
# [83]	training's binary_error: 0.3062	valid_1's binary_error: 0.33896
# [84]	training's binary_error: 0.30582	valid_1's binary_error: 0.33864
# [85]	training's binary_error: 0.30536	valid_1's binary_error: 0.33838
# [86]	training's binary_error: 0.30496	valid_1's binary_error: 0.33802
# [87]	training's binary_error: 0.30436	valid_1's binary_error: 0.3381
# [88]	training's binary_error: 0.30396	valid_1's binary_error: 0.338
# [89]	training's binary_error: 0.30362	valid_1's binary_error: 0.33788
# [90]	training's binary_error: 0.30326	valid_1's binary_error: 0.33832
# [91]	training's binary_error: 0.30252	valid_1's binary_error: 0.33854
# [92]	training's binary_error: 0.30226	valid_1's binary_error: 0.33882
# [93]	training's binary_error: 0.30214	valid_1's binary_error: 0.33896
# [94]	training's binary_error: 0.30186	valid_1's binary_error: 0.339
# [95]	training's binary_error: 0.30146	valid_1's binary_error: 0.33908
# [96]	training's binary_error: 0.30126	valid_1's binary_error: 0.33902
# [97]	training's binary_error: 0.30092	valid_1's binary_error: 0.33906
# [98]	training's binary_error: 0.3005	valid_1's binary_error: 0.33876
# [99]	training's binary_error: 0.30018	valid_1's binary_error: 0.33886
# [100]	training's binary_error: 0.2999	valid_1's binary_error: 0.33884
# [101]	training's binary_error: 0.29946	valid_1's binary_error: 0.3387
# [102]	training's binary_error: 0.29916	valid_1's binary_error: 0.33896
# [103]	training's binary_error: 0.29892	valid_1's binary_error: 0.33888
# [104]	training's binary_error: 0.2986	valid_1's binary_error: 0.33906
# [105]	training's binary_error: 0.29838	valid_1's binary_error: 0.3389
# [106]	training's binary_error: 0.2981	valid_1's binary_error: 0.33898
# [107]	training's binary_error: 0.29778	valid_1's binary_error: 0.33904
# [108]	training's binary_error: 0.29746	valid_1's binary_error: 0.3388
# [109]	training's binary_error: 0.2972	valid_1's binary_error: 0.33886
# [110]	training's binary_error: 0.29666	valid_1's binary_error: 0.33896
# [111]	training's binary_error: 0.29624	valid_1's binary_error: 0.33894
# [112]	training's binary_error: 0.29614	valid_1's binary_error: 0.33896
# [113]	training's binary_error: 0.29596	valid_1's binary_error: 0.339
# [114]	training's binary_error: 0.29566	valid_1's binary_error: 0.33892
# [115]	training's binary_error: 0.29534	valid_1's binary_error: 0.33888
# [116]	training's binary_error: 0.29512	valid_1's binary_error: 0.33868
# [117]	training's binary_error: 0.29466	valid_1's binary_error: 0.33862
# [118]	training's binary_error: 0.29422	valid_1's binary_error: 0.33856
# [119]	training's binary_error: 0.29408	valid_1's binary_error: 0.33846
# [120]	training's binary_error: 0.29358	valid_1's binary_error: 0.33854
# [121]	training's binary_error: 0.2934	valid_1's binary_error: 0.33872
# [122]	training's binary_error: 0.29314	valid_1's binary_error: 0.3388
# [123]	training's binary_error: 0.29292	valid_1's binary_error: 0.3389
# [124]	training's binary_error: 0.2925	valid_1's binary_error: 0.33908
# [125]	training's binary_error: 0.29186	valid_1's binary_error: 0.33936
# [126]	training's binary_error: 0.29162	valid_1's binary_error: 0.3394
# [127]	training's binary_error: 0.2911	valid_1's binary_error: 0.3394
# [128]	training's binary_error: 0.2909	valid_1's binary_error: 0.33934
# [129]	training's binary_error: 0.29076	valid_1's binary_error: 0.33924
# [130]	training's binary_error: 0.29038	valid_1's binary_error: 0.33966
# [131]	training's binary_error: 0.28992	valid_1's binary_error: 0.3394
# [132]	training's binary_error: 0.28946	valid_1's binary_error: 0.3394
# [133]	training's binary_error: 0.28908	valid_1's binary_error: 0.33938
# [134]	training's binary_error: 0.28852	valid_1's binary_error: 0.33958
# [135]	training's binary_error: 0.28842	valid_1's binary_error: 0.3397
# [136]	training's binary_error: 0.28814	valid_1's binary_error: 0.3397
# [137]	training's binary_error: 0.28798	valid_1's binary_error: 0.33982
# [138]	training's binary_error: 0.28786	valid_1's binary_error: 0.34
# [139]	training's binary_error: 0.2875	valid_1's binary_error: 0.34
# [140]	training's binary_error: 0.28692	valid_1's binary_error: 0.34022
# [141]	training's binary_error: 0.28652	valid_1's binary_error: 0.34024
# [142]	training's binary_error: 0.28602	valid_1's binary_error: 0.34028
# [143]	training's binary_error: 0.28576	valid_1's binary_error: 0.34028
# [144]	training's binary_error: 0.28552	valid_1's binary_error: 0.34028
# [145]	training's binary_error: 0.28506	valid_1's binary_error: 0.34014
# [146]	training's binary_error: 0.28476	valid_1's binary_error: 0.34032
# [147]	training's binary_error: 0.28452	valid_1's binary_error: 0.34022
# [148]	training's binary_error: 0.28422	valid_1's binary_error: 0.34028
# [149]	training's binary_error: 0.28408	valid_1's binary_error: 0.34004
# [150]	training's binary_error: 0.28378	valid_1's binary_error: 0.33972
# [151]	training's binary_error: 0.28362	valid_1's binary_error: 0.33974
# [152]	training's binary_error: 0.28352	valid_1's binary_error: 0.33954
# [153]	training's binary_error: 0.28304	valid_1's binary_error: 0.3392
# [154]	training's binary_error: 0.28266	valid_1's binary_error: 0.33946
# [155]	training's binary_error: 0.28242	valid_1's binary_error: 0.33962
# [156]	training's binary_error: 0.28216	valid_1's binary_error: 0.33962
# [157]	training's binary_error: 0.28192	valid_1's binary_error: 0.33986
# [158]	training's binary_error: 0.28186	valid_1's binary_error: 0.33984
# [159]	training's binary_error: 0.28166	valid_1's binary_error: 0.33978
# [160]	training's binary_error: 0.2812	valid_1's binary_error: 0.33982
# [161]	training's binary_error: 0.28106	valid_1's binary_error: 0.34
# [162]	training's binary_error: 0.28068	valid_1's binary_error: 0.33998
# [163]	training's binary_error: 0.28064	valid_1's binary_error: 0.33966
# [164]	training's binary_error: 0.28034	valid_1's binary_error: 0.3399
# [165]	training's binary_error: 0.28	valid_1's binary_error: 0.33986
# [166]	training's binary_error: 0.27998	valid_1's binary_error: 0.33968
# [167]	training's binary_error: 0.27988	valid_1's binary_error: 0.33986
# [168]	training's binary_error: 0.2794	valid_1's binary_error: 0.33996
# [169]	training's binary_error: 0.27918	valid_1's binary_error: 0.33996
# [170]	training's binary_error: 0.27906	valid_1's binary_error: 0.3398
# [171]	training's binary_error: 0.27846	valid_1's binary_error: 0.33978
# [172]	training's binary_error: 0.27806	valid_1's binary_error: 0.33986
# [173]	training's binary_error: 0.27798	valid_1's binary_error: 0.33984
# [174]	training's binary_error: 0.2778	valid_1's binary_error: 0.33984
# [175]	training's binary_error: 0.27746	valid_1's binary_error: 0.33984
# [176]	training's binary_error: 0.27746	valid_1's binary_error: 0.34002
# [177]	training's binary_error: 0.27694	valid_1's binary_error: 0.34022
# [178]	training's binary_error: 0.27688	valid_1's binary_error: 0.34018
# [179]	training's binary_error: 0.27652	valid_1's binary_error: 0.3402
# [180]	training's binary_error: 0.27642	valid_1's binary_error: 0.3403
# [181]	training's binary_error: 0.27604	valid_1's binary_error: 0.34058
# [182]	training's binary_error: 0.27594	valid_1's binary_error: 0.34046
# [183]	training's binary_error: 0.2756	valid_1's binary_error: 0.34028
# [184]	training's binary_error: 0.2755	valid_1's binary_error: 0.34038
# [185]	training's binary_error: 0.2751	valid_1's binary_error: 0.34034
# [186]	training's binary_error: 0.2748	valid_1's binary_error: 0.34036
# [187]	training's binary_error: 0.27476	valid_1's binary_error: 0.34046
# [188]	training's binary_error: 0.27446	valid_1's binary_error: 0.34046
# [189]	training's binary_error: 0.27414	valid_1's binary_error: 0.3405
# [190]	training's binary_error: 0.27398	valid_1's binary_error: 0.3407
# [191]	training's binary_error: 0.27352	valid_1's binary_error: 0.34062
# [192]	training's binary_error: 0.2732	valid_1's binary_error: 0.34066
# [193]	training's binary_error: 0.27284	valid_1's binary_error: 0.34062
# [194]	training's binary_error: 0.27258	valid_1's binary_error: 0.34052
# [195]	training's binary_error: 0.2724	valid_1's binary_error: 0.34064
# [196]	training's binary_error: 0.2723	valid_1's binary_error: 0.3404
# [197]	training's binary_error: 0.27228	valid_1's binary_error: 0.34034
# [198]	training's binary_error: 0.27224	valid_1's binary_error: 0.34024
# [199]	training's binary_error: 0.27206	valid_1's binary_error: 0.34002
# [200]	training's binary_error: 0.27174	valid_1's binary_error: 0.3401
# [201]	training's binary_error: 0.27168	valid_1's binary_error: 0.34032
# [202]	training's binary_error: 0.27166	valid_1's binary_error: 0.34022
# [203]	training's binary_error: 0.27128	valid_1's binary_error: 0.34026
# [204]	training's binary_error: 0.2712	valid_1's binary_error: 0.34022
# [205]	training's binary_error: 0.27108	valid_1's binary_error: 0.34038
# [206]	training's binary_error: 0.27064	valid_1's binary_error: 0.34016
# [207]	training's binary_error: 0.27034	valid_1's binary_error: 0.34012
# [208]	training's binary_error: 0.27038	valid_1's binary_error: 0.34022
# [209]	training's binary_error: 0.27012	valid_1's binary_error: 0.34016
# [210]	training's binary_error: 0.26992	valid_1's binary_error: 0.3402
# [211]	training's binary_error: 0.2698	valid_1's binary_error: 0.34032
# [212]	training's binary_error: 0.26926	valid_1's binary_error: 0.34036
# [213]	training's binary_error: 0.26914	valid_1's binary_error: 0.34036
# [214]	training's binary_error: 0.26906	valid_1's binary_error: 0.34032
# [215]	training's binary_error: 0.26862	valid_1's binary_error: 0.34036
# [216]	training's binary_error: 0.2681	valid_1's binary_error: 0.34048
# [217]	training's binary_error: 0.2678	valid_1's binary_error: 0.34056
# [218]	training's binary_error: 0.26738	valid_1's binary_error: 0.34052
# [219]	training's binary_error: 0.26714	valid_1's binary_error: 0.3405
# [220]	training's binary_error: 0.26696	valid_1's binary_error: 0.34038
# [221]	training's binary_error: 0.26668	valid_1's binary_error: 0.3406
# [222]	training's binary_error: 0.26662	valid_1's binary_error: 0.34056
# [223]	training's binary_error: 0.2662	valid_1's binary_error: 0.34056
# [224]	training's binary_error: 0.26602	valid_1's binary_error: 0.34054
# [225]	training's binary_error: 0.266	valid_1's binary_error: 0.34052
# [226]	training's binary_error: 0.26558	valid_1's binary_error: 0.34068
# [227]	training's binary_error: 0.26534	valid_1's binary_error: 0.34052
# [228]	training's binary_error: 0.265	valid_1's binary_error: 0.34054
# [229]	training's binary_error: 0.26474	valid_1's binary_error: 0.3406
# [230]	training's binary_error: 0.2644	valid_1's binary_error: 0.34062
# [231]	training's binary_error: 0.26422	valid_1's binary_error: 0.34064
# [232]	training's binary_error: 0.264	valid_1's binary_error: 0.3407
# [233]	training's binary_error: 0.26368	valid_1's binary_error: 0.34074
# [234]	training's binary_error: 0.26348	valid_1's binary_error: 0.34094
# [235]	training's binary_error: 0.26334	valid_1's binary_error: 0.34106
# [236]	training's binary_error: 0.26302	valid_1's binary_error: 0.34126
# [237]	training's binary_error: 0.26276	valid_1's binary_error: 0.3417
# [238]	training's binary_error: 0.2626	valid_1's binary_error: 0.34208
# [239]	training's binary_error: 0.26252	valid_1's binary_error: 0.342
# [240]	training's binary_error: 0.26226	valid_1's binary_error: 0.34192
# [241]	training's binary_error: 0.26198	valid_1's binary_error: 0.34174
# [242]	training's binary_error: 0.26194	valid_1's binary_error: 0.3416
# [243]	training's binary_error: 0.26172	valid_1's binary_error: 0.34124
# [244]	training's binary_error: 0.2613	valid_1's binary_error: 0.34134
# [245]	training's binary_error: 0.26128	valid_1's binary_error: 0.34138
# [246]	training's binary_error: 0.26104	valid_1's binary_error: 0.34112
# [247]	training's binary_error: 0.2608	valid_1's binary_error: 0.34118
# [248]	training's binary_error: 0.26042	valid_1's binary_error: 0.34112
# [249]	training's binary_error: 0.2601	valid_1's binary_error: 0.34106
# [250]	training's binary_error: 0.2598	valid_1's binary_error: 0.34116
# [251]	training's binary_error: 0.25952	valid_1's binary_error: 0.34128
# [252]	training's binary_error: 0.2592	valid_1's binary_error: 0.34134
# [253]	training's binary_error: 0.25896	valid_1's binary_error: 0.3413
# [254]	training's binary_error: 0.2584	valid_1's binary_error: 0.34176
# [255]	training's binary_error: 0.25832	valid_1's binary_error: 0.34176
# [256]	training's binary_error: 0.2582	valid_1's binary_error: 0.3418
# [257]	training's binary_error: 0.258	valid_1's binary_error: 0.34188
# [258]	training's binary_error: 0.25778	valid_1's binary_error: 0.34182
# [259]	training's binary_error: 0.25754	valid_1's binary_error: 0.34218
# [260]	training's binary_error: 0.2572	valid_1's binary_error: 0.34228
# [261]	training's binary_error: 0.2569	valid_1's binary_error: 0.34238
# [262]	training's binary_error: 0.25674	valid_1's binary_error: 0.34224
# [263]	training's binary_error: 0.25652	valid_1's binary_error: 0.34198
# [264]	training's binary_error: 0.25638	valid_1's binary_error: 0.34192
# [265]	training's binary_error: 0.25612	valid_1's binary_error: 0.34188
# [266]	training's binary_error: 0.25602	valid_1's binary_error: 0.34164
# [267]	training's binary_error: 0.25588	valid_1's binary_error: 0.34154
# [268]	training's binary_error: 0.25558	valid_1's binary_error: 0.34168
# [269]	training's binary_error: 0.2555	valid_1's binary_error: 0.34172
# [270]	training's binary_error: 0.25522	valid_1's binary_error: 0.34156
# [271]	training's binary_error: 0.2549	valid_1's binary_error: 0.3416
# [272]	training's binary_error: 0.25474	valid_1's binary_error: 0.34172
# [273]	training's binary_error: 0.2545	valid_1's binary_error: 0.34168
# [274]	training's binary_error: 0.2543	valid_1's binary_error: 0.34172
# [275]	training's binary_error: 0.25398	valid_1's binary_error: 0.34162
# [276]	training's binary_error: 0.2538	valid_1's binary_error: 0.34164
# [277]	training's binary_error: 0.25372	valid_1's binary_error: 0.34198
# [278]	training's binary_error: 0.25342	valid_1's binary_error: 0.34172
# [279]	training's binary_error: 0.2533	valid_1's binary_error: 0.3418
# [280]	training's binary_error: 0.2528	valid_1's binary_error: 0.3419
# [281]	training's binary_error: 0.25268	valid_1's binary_error: 0.34214
# [282]	training's binary_error: 0.25236	valid_1's binary_error: 0.34216
# [283]	training's binary_error: 0.25192	valid_1's binary_error: 0.34244
# [284]	training's binary_error: 0.25158	valid_1's binary_error: 0.34266
# [285]	training's binary_error: 0.25128	valid_1's binary_error: 0.34268
# [286]	training's binary_error: 0.251	valid_1's binary_error: 0.34262
# [287]	training's binary_error: 0.2508	valid_1's binary_error: 0.34266
# [288]	training's binary_error: 0.25058	valid_1's binary_error: 0.34262
# [289]	training's binary_error: 0.25014	valid_1's binary_error: 0.34266
# [290]	training's binary_error: 0.25016	valid_1's binary_error: 0.34266
# [291]	training's binary_error: 0.24996	valid_1's binary_error: 0.34266
# [292]	training's binary_error: 0.24976	valid_1's binary_error: 0.34258
# [293]	training's binary_error: 0.24952	valid_1's binary_error: 0.34266
# [294]	training's binary_error: 0.24926	valid_1's binary_error: 0.34292
# [295]	training's binary_error: 0.24908	valid_1's binary_error: 0.34268
# [296]	training's binary_error: 0.24892	valid_1's binary_error: 0.34254
# [297]	training's binary_error: 0.24854	valid_1's binary_error: 0.3427
# [298]	training's binary_error: 0.248	valid_1's binary_error: 0.34318
# [299]	training's binary_error: 0.24796	valid_1's binary_error: 0.34306
# [300]	training's binary_error: 0.2475	valid_1's binary_error: 0.34318
# [301]	training's binary_error: 0.2472	valid_1's binary_error: 0.34304
# [302]	training's binary_error: 0.24702	valid_1's binary_error: 0.34304
# [303]	training's binary_error: 0.24694	valid_1's binary_error: 0.34302
# [304]	training's binary_error: 0.24676	valid_1's binary_error: 0.3431
# [305]	training's binary_error: 0.24652	valid_1's binary_error: 0.34318
# [306]	training's binary_error: 0.24616	valid_1's binary_error: 0.3431
# [307]	training's binary_error: 0.24582	valid_1's binary_error: 0.34308
# [308]	training's binary_error: 0.2455	valid_1's binary_error: 0.34308
# [309]	training's binary_error: 0.24532	valid_1's binary_error: 0.34302
# [310]	training's binary_error: 0.24516	valid_1's binary_error: 0.34292
# [311]	training's binary_error: 0.24498	valid_1's binary_error: 0.34298
# [312]	training's binary_error: 0.24468	valid_1's binary_error: 0.34308
# [313]	training's binary_error: 0.2445	valid_1's binary_error: 0.34308
# [314]	training's binary_error: 0.24402	valid_1's binary_error: 0.34328
# [315]	training's binary_error: 0.24364	valid_1's binary_error: 0.34324
# [316]	training's binary_error: 0.24334	valid_1's binary_error: 0.34324
# [317]	training's binary_error: 0.24302	valid_1's binary_error: 0.34326
# [318]	training's binary_error: 0.24268	valid_1's binary_error: 0.34354
# [319]	training's binary_error: 0.24264	valid_1's binary_error: 0.34346
# [320]	training's binary_error: 0.24246	valid_1's binary_error: 0.34326
# [321]	training's binary_error: 0.24222	valid_1's binary_error: 0.34332
# [322]	training's binary_error: 0.24194	valid_1's binary_error: 0.34328
# [323]	training's binary_error: 0.24172	valid_1's binary_error: 0.34314
# [324]	training's binary_error: 0.24166	valid_1's binary_error: 0.34298
# [325]	training's binary_error: 0.24176	valid_1's binary_error: 0.34292
# [326]	training's binary_error: 0.24158	valid_1's binary_error: 0.3429
# [327]	training's binary_error: 0.2412	valid_1's binary_error: 0.34288
# [328]	training's binary_error: 0.24096	valid_1's binary_error: 0.3428
# [329]	training's binary_error: 0.24076	valid_1's binary_error: 0.3428
# [330]	training's binary_error: 0.24074	valid_1's binary_error: 0.34282
# [331]	training's binary_error: 0.24044	valid_1's binary_error: 0.34284
# [332]	training's binary_error: 0.2401	valid_1's binary_error: 0.3427
# [333]	training's binary_error: 0.23992	valid_1's binary_error: 0.34274
# [334]	training's binary_error: 0.23992	valid_1's binary_error: 0.34268
# [335]	training's binary_error: 0.2398	valid_1's binary_error: 0.34282
# [336]	training's binary_error: 0.23974	valid_1's binary_error: 0.34296
# [337]	training's binary_error: 0.23942	valid_1's binary_error: 0.34294
# [338]	training's binary_error: 0.23922	valid_1's binary_error: 0.34286
# [339]	training's binary_error: 0.23894	valid_1's binary_error: 0.3428
# [340]	training's binary_error: 0.2388	valid_1's binary_error: 0.34272
# [341]	training's binary_error: 0.23834	valid_1's binary_error: 0.34272
# [342]	training's binary_error: 0.23804	valid_1's binary_error: 0.34274
# [343]	training's binary_error: 0.23778	valid_1's binary_error: 0.34274
# [344]	training's binary_error: 0.2376	valid_1's binary_error: 0.34274
# [345]	training's binary_error: 0.23734	valid_1's binary_error: 0.34268
# [346]	training's binary_error: 0.2373	valid_1's binary_error: 0.34284
# [347]	training's binary_error: 0.2372	valid_1's binary_error: 0.34268
# [348]	training's binary_error: 0.23686	valid_1's binary_error: 0.34274
# [349]	training's binary_error: 0.23668	valid_1's binary_error: 0.34284
# [350]	training's binary_error: 0.23648	valid_1's binary_error: 0.34288
# [351]	training's binary_error: 0.23614	valid_1's binary_error: 0.34266
# [352]	training's binary_error: 0.23606	valid_1's binary_error: 0.34278
# [353]	training's binary_error: 0.23602	valid_1's binary_error: 0.3428
# [354]	training's binary_error: 0.23594	valid_1's binary_error: 0.34262
# [355]	training's binary_error: 0.23554	valid_1's binary_error: 0.34282
# [356]	training's binary_error: 0.23538	valid_1's binary_error: 0.34286
# [357]	training's binary_error: 0.23498	valid_1's binary_error: 0.34304
# [358]	training's binary_error: 0.2348	valid_1's binary_error: 0.3431
# [359]	training's binary_error: 0.23488	valid_1's binary_error: 0.34296
# [360]	training's binary_error: 0.2347	valid_1's binary_error: 0.34306
# [361]	training's binary_error: 0.23466	valid_1's binary_error: 0.34312
# [362]	training's binary_error: 0.2343	valid_1's binary_error: 0.343
# [363]	training's binary_error: 0.23422	valid_1's binary_error: 0.34288
# [364]	training's binary_error: 0.23396	valid_1's binary_error: 0.34284
# [365]	training's binary_error: 0.2336	valid_1's binary_error: 0.34274
# [366]	training's binary_error: 0.2335	valid_1's binary_error: 0.34242
# [367]	training's binary_error: 0.23328	valid_1's binary_error: 0.34248
# [368]	training's binary_error: 0.2331	valid_1's binary_error: 0.3424
# [369]	training's binary_error: 0.2329	valid_1's binary_error: 0.34246
# [370]	training's binary_error: 0.23276	valid_1's binary_error: 0.34258
# [371]	training's binary_error: 0.23256	valid_1's binary_error: 0.34256
# [372]	training's binary_error: 0.23242	valid_1's binary_error: 0.34264
# [373]	training's binary_error: 0.23204	valid_1's binary_error: 0.3427
# [374]	training's binary_error: 0.23182	valid_1's binary_error: 0.34284
# [375]	training's binary_error: 0.23158	valid_1's binary_error: 0.34284
# [376]	training's binary_error: 0.2316	valid_1's binary_error: 0.3429
# [377]	training's binary_error: 0.23122	valid_1's binary_error: 0.3428
# [378]	training's binary_error: 0.23076	valid_1's binary_error: 0.34274
# [379]	training's binary_error: 0.23038	valid_1's binary_error: 0.3427
# [380]	training's binary_error: 0.23008	valid_1's binary_error: 0.3427
# [381]	training's binary_error: 0.22956	valid_1's binary_error: 0.34288
# [382]	training's binary_error: 0.2292	valid_1's binary_error: 0.3429
# [383]	training's binary_error: 0.22888	valid_1's binary_error: 0.3427
# [384]	training's binary_error: 0.22868	valid_1's binary_error: 0.34254
# [385]	training's binary_error: 0.22862	valid_1's binary_error: 0.34246
# [386]	training's binary_error: 0.22834	valid_1's binary_error: 0.3427
# [387]	training's binary_error: 0.22826	valid_1's binary_error: 0.34276
# [388]	training's binary_error: 0.2279	valid_1's binary_error: 0.34284
# [389]	training's binary_error: 0.22752	valid_1's binary_error: 0.34286
# [390]	training's binary_error: 0.22748	valid_1's binary_error: 0.3426
# [391]	training's binary_error: 0.22728	valid_1's binary_error: 0.3427
# [392]	training's binary_error: 0.22722	valid_1's binary_error: 0.3427
# [393]	training's binary_error: 0.22678	valid_1's binary_error: 0.34258
# [394]	training's binary_error: 0.22634	valid_1's binary_error: 0.34266
# [395]	training's binary_error: 0.22618	valid_1's binary_error: 0.34292
# [396]	training's binary_error: 0.22614	valid_1's binary_error: 0.34298
# [397]	training's binary_error: 0.22598	valid_1's binary_error: 0.3431
# [398]	training's binary_error: 0.22566	valid_1's binary_error: 0.3433
# [399]	training's binary_error: 0.22528	valid_1's binary_error: 0.34296
# [400]	training's binary_error: 0.22486	valid_1's binary_error: 0.34294
# [401]	training's binary_error: 0.22456	valid_1's binary_error: 0.34296
# [402]	training's binary_error: 0.2245	valid_1's binary_error: 0.34296
# [403]	training's binary_error: 0.22454	valid_1's binary_error: 0.34294
# [404]	training's binary_error: 0.2244	valid_1's binary_error: 0.34304
# [405]	training's binary_error: 0.22434	valid_1's binary_error: 0.34296
# [406]	training's binary_error: 0.2242	valid_1's binary_error: 0.34318
# [407]	training's binary_error: 0.22398	valid_1's binary_error: 0.34308
# [408]	training's binary_error: 0.22386	valid_1's binary_error: 0.3433
# [409]	training's binary_error: 0.22366	valid_1's binary_error: 0.34344
# [410]	training's binary_error: 0.22352	valid_1's binary_error: 0.34324
# [411]	training's binary_error: 0.22338	valid_1's binary_error: 0.34318
# [412]	training's binary_error: 0.22314	valid_1's binary_error: 0.34322
# [413]	training's binary_error: 0.22268	valid_1's binary_error: 0.34338
# [414]	training's binary_error: 0.22262	valid_1's binary_error: 0.34336
# [415]	training's binary_error: 0.22262	valid_1's binary_error: 0.34326
# [416]	training's binary_error: 0.2224	valid_1's binary_error: 0.34328
# [417]	training's binary_error: 0.22238	valid_1's binary_error: 0.34338
# [418]	training's binary_error: 0.22242	valid_1's binary_error: 0.34338
# [419]	training's binary_error: 0.2221	valid_1's binary_error: 0.34346
# [420]	training's binary_error: 0.22194	valid_1's binary_error: 0.34336
# [421]	training's binary_error: 0.22196	valid_1's binary_error: 0.34334
# [422]	training's binary_error: 0.22182	valid_1's binary_error: 0.3434
# [423]	training's binary_error: 0.22164	valid_1's binary_error: 0.34324
# [424]	training's binary_error: 0.22146	valid_1's binary_error: 0.34316
# [425]	training's binary_error: 0.22114	valid_1's binary_error: 0.34314
# [426]	training's binary_error: 0.22098	valid_1's binary_error: 0.3432
# [427]	training's binary_error: 0.22078	valid_1's binary_error: 0.34312
# [428]	training's binary_error: 0.2205	valid_1's binary_error: 0.3432
# [429]	training's binary_error: 0.22016	valid_1's binary_error: 0.34344
# [430]	training's binary_error: 0.22012	valid_1's binary_error: 0.34354
# [431]	training's binary_error: 0.2199	valid_1's binary_error: 0.34374
# [432]	training's binary_error: 0.21984	valid_1's binary_error: 0.34376
# [433]	training's binary_error: 0.21952	valid_1's binary_error: 0.3438
# [434]	training's binary_error: 0.21926	valid_1's binary_error: 0.3438
# [435]	training's binary_error: 0.21906	valid_1's binary_error: 0.34374
# [436]	training's binary_error: 0.21888	valid_1's binary_error: 0.3439
# [437]	training's binary_error: 0.21854	valid_1's binary_error: 0.34396
# [438]	training's binary_error: 0.21834	valid_1's binary_error: 0.34388
# [439]	training's binary_error: 0.21792	valid_1's binary_error: 0.3439
# [440]	training's binary_error: 0.21784	valid_1's binary_error: 0.3439
# [441]	training's binary_error: 0.21752	valid_1's binary_error: 0.34394
# [442]	training's binary_error: 0.2174	valid_1's binary_error: 0.34404
# [443]	training's binary_error: 0.21724	valid_1's binary_error: 0.34406
# [444]	training's binary_error: 0.21718	valid_1's binary_error: 0.3442
# [445]	training's binary_error: 0.21702	valid_1's binary_error: 0.3441
# [446]	training's binary_error: 0.217	valid_1's binary_error: 0.34418
# [447]	training's binary_error: 0.2169	valid_1's binary_error: 0.3441
# [448]	training's binary_error: 0.21672	valid_1's binary_error: 0.34414
# [449]	training's binary_error: 0.21666	valid_1's binary_error: 0.34406
# [450]	training's binary_error: 0.21646	valid_1's binary_error: 0.34404
# [451]	training's binary_error: 0.21618	valid_1's binary_error: 0.3439
# [452]	training's binary_error: 0.2162	valid_1's binary_error: 0.34378
# [453]	training's binary_error: 0.21616	valid_1's binary_error: 0.34368
# [454]	training's binary_error: 0.21608	valid_1's binary_error: 0.34382
# [455]	training's binary_error: 0.2161	valid_1's binary_error: 0.34402
# [456]	training's binary_error: 0.21538	valid_1's binary_error: 0.34402
# [457]	training's binary_error: 0.2152	valid_1's binary_error: 0.34398
# [458]	training's binary_error: 0.21508	valid_1's binary_error: 0.344
# [459]	training's binary_error: 0.2147	valid_1's binary_error: 0.344
# [460]	training's binary_error: 0.21458	valid_1's binary_error: 0.34426
# [461]	training's binary_error: 0.21436	valid_1's binary_error: 0.34418
# [462]	training's binary_error: 0.2143	valid_1's binary_error: 0.34416
# [463]	training's binary_error: 0.2141	valid_1's binary_error: 0.34414
# [464]	training's binary_error: 0.21372	valid_1's binary_error: 0.3442
# [465]	training's binary_error: 0.21344	valid_1's binary_error: 0.34422
# [466]	training's binary_error: 0.21336	valid_1's binary_error: 0.34408
# [467]	training's binary_error: 0.2132	valid_1's binary_error: 0.34422
# [468]	training's binary_error: 0.21304	valid_1's binary_error: 0.34424
# [469]	training's binary_error: 0.21272	valid_1's binary_error: 0.34412
# [470]	training's binary_error: 0.21264	valid_1's binary_error: 0.34404
# [471]	training's binary_error: 0.21256	valid_1's binary_error: 0.34408
# [472]	training's binary_error: 0.2124	valid_1's binary_error: 0.3441
# [473]	training's binary_error: 0.21232	valid_1's binary_error: 0.34414
# [474]	training's binary_error: 0.21234	valid_1's binary_error: 0.34428
# [475]	training's binary_error: 0.21224	valid_1's binary_error: 0.34448
# [476]	training's binary_error: 0.21166	valid_1's binary_error: 0.34464
# [477]	training's binary_error: 0.21158	valid_1's binary_error: 0.3449
# [478]	training's binary_error: 0.21142	valid_1's binary_error: 0.34478
# [479]	training's binary_error: 0.21126	valid_1's binary_error: 0.34512
# [480]	training's binary_error: 0.21114	valid_1's binary_error: 0.34528
# [481]	training's binary_error: 0.21074	valid_1's binary_error: 0.34536
# [482]	training's binary_error: 0.21062	valid_1's binary_error: 0.34542
# [483]	training's binary_error: 0.21062	valid_1's binary_error: 0.34536
# [484]	training's binary_error: 0.2104	valid_1's binary_error: 0.3455
# [485]	training's binary_error: 0.21022	valid_1's binary_error: 0.34562
# [486]	training's binary_error: 0.20998	valid_1's binary_error: 0.34568
# [487]	training's binary_error: 0.2097	valid_1's binary_error: 0.3457
# [488]	training's binary_error: 0.20946	valid_1's binary_error: 0.34584
# [489]	training's binary_error: 0.20916	valid_1's binary_error: 0.34568
# [490]	training's binary_error: 0.20902	valid_1's binary_error: 0.3457
# [491]	training's binary_error: 0.20874	valid_1's binary_error: 0.34584
# [492]	training's binary_error: 0.20848	valid_1's binary_error: 0.3459
# [493]	training's binary_error: 0.20836	valid_1's binary_error: 0.3459
# [494]	training's binary_error: 0.20834	valid_1's binary_error: 0.34592
# [495]	training's binary_error: 0.2082	valid_1's binary_error: 0.34592
# [496]	training's binary_error: 0.20788	valid_1's binary_error: 0.34552
# [497]	training's binary_error: 0.20776	valid_1's binary_error: 0.3454
# [498]	training's binary_error: 0.20752	valid_1's binary_error: 0.3453
# [499]	training's binary_error: 0.20724	valid_1's binary_error: 0.34548
# [500]	training's binary_error: 0.20706	valid_1's binary_error: 0.34552
# [501]	training's binary_error: 0.20684	valid_1's binary_error: 0.34556
# [502]	training's binary_error: 0.20672	valid_1's binary_error: 0.34542
# [503]	training's binary_error: 0.20658	valid_1's binary_error: 0.34544
# [504]	training's binary_error: 0.2064	valid_1's binary_error: 0.34566
# [505]	training's binary_error: 0.2061	valid_1's binary_error: 0.34576
# [506]	training's binary_error: 0.20588	valid_1's binary_error: 0.3457
# [507]	training's binary_error: 0.20556	valid_1's binary_error: 0.34586
# [508]	training's binary_error: 0.20548	valid_1's binary_error: 0.34586
# [509]	training's binary_error: 0.20532	valid_1's binary_error: 0.3458
# [510]	training's binary_error: 0.20524	valid_1's binary_error: 0.34572
# [511]	training's binary_error: 0.20512	valid_1's binary_error: 0.34568
# [512]	training's binary_error: 0.20492	valid_1's binary_error: 0.34562
# [513]	training's binary_error: 0.20476	valid_1's binary_error: 0.34574
# [514]	training's binary_error: 0.20462	valid_1's binary_error: 0.346
# [515]	training's binary_error: 0.20422	valid_1's binary_error: 0.34598
# [516]	training's binary_error: 0.20418	valid_1's binary_error: 0.34586
# [517]	training's binary_error: 0.20398	valid_1's binary_error: 0.34584
# [518]	training's binary_error: 0.20392	valid_1's binary_error: 0.34586
# [519]	training's binary_error: 0.20382	valid_1's binary_error: 0.34584
# [520]	training's binary_error: 0.2036	valid_1's binary_error: 0.34572
# [521]	training's binary_error: 0.2035	valid_1's binary_error: 0.34598
# [522]	training's binary_error: 0.20346	valid_1's binary_error: 0.34578
# [523]	training's binary_error: 0.20312	valid_1's binary_error: 0.34594
# [524]	training's binary_error: 0.2027	valid_1's binary_error: 0.34598
# [525]	training's binary_error: 0.2025	valid_1's binary_error: 0.34596
# [526]	training's binary_error: 0.20228	valid_1's binary_error: 0.34612
# [527]	training's binary_error: 0.20214	valid_1's binary_error: 0.34616
# [528]	training's binary_error: 0.20172	valid_1's binary_error: 0.3461
# [529]	training's binary_error: 0.20154	valid_1's binary_error: 0.34616
# [530]	training's binary_error: 0.20134	valid_1's binary_error: 0.34606
# [531]	training's binary_error: 0.20118	valid_1's binary_error: 0.34618
# [532]	training's binary_error: 0.20086	valid_1's binary_error: 0.34618
# [533]	training's binary_error: 0.20058	valid_1's binary_error: 0.34624
# [534]	training's binary_error: 0.20064	valid_1's binary_error: 0.3463
# [535]	training's binary_error: 0.2005	valid_1's binary_error: 0.34616
# [536]	training's binary_error: 0.2003	valid_1's binary_error: 0.346
# [537]	training's binary_error: 0.20018	valid_1's binary_error: 0.34576
# [538]	training's binary_error: 0.20014	valid_1's binary_error: 0.34584
# [539]	training's binary_error: 0.20006	valid_1's binary_error: 0.34584
# [540]	training's binary_error: 0.19984	valid_1's binary_error: 0.3459
# [541]	training's binary_error: 0.19956	valid_1's binary_error: 0.34592
# [542]	training's binary_error: 0.19936	valid_1's binary_error: 0.34592
# [543]	training's binary_error: 0.1992	valid_1's binary_error: 0.34556
# [544]	training's binary_error: 0.19896	valid_1's binary_error: 0.3456
# [545]	training's binary_error: 0.1987	valid_1's binary_error: 0.34554
# [546]	training's binary_error: 0.19846	valid_1's binary_error: 0.34552
# [547]	training's binary_error: 0.19842	valid_1's binary_error: 0.34552
# [548]	training's binary_error: 0.1984	valid_1's binary_error: 0.34552
# [549]	training's binary_error: 0.19834	valid_1's binary_error: 0.34548
# [550]	training's binary_error: 0.19804	valid_1's binary_error: 0.34526
# [551]	training's binary_error: 0.19782	valid_1's binary_error: 0.34528
# [552]	training's binary_error: 0.19768	valid_1's binary_error: 0.34528
# [553]	training's binary_error: 0.19744	valid_1's binary_error: 0.34524
# [554]	training's binary_error: 0.19724	valid_1's binary_error: 0.34536
# [555]	training's binary_error: 0.19724	valid_1's binary_error: 0.3453
# [556]	training's binary_error: 0.19708	valid_1's binary_error: 0.34542
# [557]	training's binary_error: 0.19688	valid_1's binary_error: 0.34552
# [558]	training's binary_error: 0.1968	valid_1's binary_error: 0.34566
# [559]	training's binary_error: 0.19674	valid_1's binary_error: 0.3456
# [560]	training's binary_error: 0.19642	valid_1's binary_error: 0.3455
# [561]	training's binary_error: 0.19598	valid_1's binary_error: 0.34542
# [562]	training's binary_error: 0.19594	valid_1's binary_error: 0.34528
# [563]	training's binary_error: 0.1958	valid_1's binary_error: 0.34536
# [564]	training's binary_error: 0.19552	valid_1's binary_error: 0.34514
# [565]	training's binary_error: 0.1954	valid_1's binary_error: 0.34506
# [566]	training's binary_error: 0.19526	valid_1's binary_error: 0.34512
# [567]	training's binary_error: 0.19482	valid_1's binary_error: 0.34526
# [568]	training's binary_error: 0.1946	valid_1's binary_error: 0.34526
# [569]	training's binary_error: 0.19456	valid_1's binary_error: 0.34546
# [570]	training's binary_error: 0.1945	valid_1's binary_error: 0.3453
# [571]	training's binary_error: 0.19436	valid_1's binary_error: 0.34552
# [572]	training's binary_error: 0.19434	valid_1's binary_error: 0.34552
# [573]	training's binary_error: 0.19404	valid_1's binary_error: 0.34554
# [574]	training's binary_error: 0.19404	valid_1's binary_error: 0.3457
# [575]	training's binary_error: 0.1941	valid_1's binary_error: 0.34578
# [576]	training's binary_error: 0.19402	valid_1's binary_error: 0.34594
# [577]	training's binary_error: 0.1937	valid_1's binary_error: 0.346
# [578]	training's binary_error: 0.19328	valid_1's binary_error: 0.34604
# [579]	training's binary_error: 0.19312	valid_1's binary_error: 0.34602
# [580]	training's binary_error: 0.19286	valid_1's binary_error: 0.34604
# [581]	training's binary_error: 0.19274	valid_1's binary_error: 0.34612
# [582]	training's binary_error: 0.19256	valid_1's binary_error: 0.34618
# [583]	training's binary_error: 0.19232	valid_1's binary_error: 0.34618
# [584]	training's binary_error: 0.19216	valid_1's binary_error: 0.34612
# [585]	training's binary_error: 0.19222	valid_1's binary_error: 0.34622
# [586]	training's binary_error: 0.19222	valid_1's binary_error: 0.34616
# [587]	training's binary_error: 0.1917	valid_1's binary_error: 0.34626
# [588]	training's binary_error: 0.19138	valid_1's binary_error: 0.34626
# [589]	training's binary_error: 0.19126	valid_1's binary_error: 0.34626
# [590]	training's binary_error: 0.19118	valid_1's binary_error: 0.34628
# [591]	training's binary_error: 0.19086	valid_1's binary_error: 0.34632
# [592]	training's binary_error: 0.19078	valid_1's binary_error: 0.3462
# [593]	training's binary_error: 0.19054	valid_1's binary_error: 0.34628
# [594]	training's binary_error: 0.19046	valid_1's binary_error: 0.3465
# [595]	training's binary_error: 0.1902	valid_1's binary_error: 0.3464
# [596]	training's binary_error: 0.19006	valid_1's binary_error: 0.34618
# [597]	training's binary_error: 0.18992	valid_1's binary_error: 0.3463
# [598]	training's binary_error: 0.18986	valid_1's binary_error: 0.34628
# [599]	training's binary_error: 0.18974	valid_1's binary_error: 0.34648
# [600]	training's binary_error: 0.18952	valid_1's binary_error: 0.34656
# [601]	training's binary_error: 0.18946	valid_1's binary_error: 0.34654
# [602]	training's binary_error: 0.1891	valid_1's binary_error: 0.34666
# [603]	training's binary_error: 0.18906	valid_1's binary_error: 0.34668
# [604]	training's binary_error: 0.18898	valid_1's binary_error: 0.34668
# [605]	training's binary_error: 0.18882	valid_1's binary_error: 0.34678
# [606]	training's binary_error: 0.18852	valid_1's binary_error: 0.34682
# [607]	training's binary_error: 0.1884	valid_1's binary_error: 0.34666
# [608]	training's binary_error: 0.18812	valid_1's binary_error: 0.34662
# [609]	training's binary_error: 0.1879	valid_1's binary_error: 0.34658
# [610]	training's binary_error: 0.18758	valid_1's binary_error: 0.34684
# [611]	training's binary_error: 0.18736	valid_1's binary_error: 0.34694
# [612]	training's binary_error: 0.1872	valid_1's binary_error: 0.34696
# [613]	training's binary_error: 0.1871	valid_1's binary_error: 0.34698
# [614]	training's binary_error: 0.18678	valid_1's binary_error: 0.34676
# [615]	training's binary_error: 0.18654	valid_1's binary_error: 0.34696
# [616]	training's binary_error: 0.1863	valid_1's binary_error: 0.34684
# [617]	training's binary_error: 0.18624	valid_1's binary_error: 0.34682
# [618]	training's binary_error: 0.18614	valid_1's binary_error: 0.34682
# [619]	training's binary_error: 0.1861	valid_1's binary_error: 0.34684
# [620]	training's binary_error: 0.1859	valid_1's binary_error: 0.34684
# [621]	training's binary_error: 0.18564	valid_1's binary_error: 0.34684
# [622]	training's binary_error: 0.18556	valid_1's binary_error: 0.34686
# [623]	training's binary_error: 0.18532	valid_1's binary_error: 0.34678
# [624]	training's binary_error: 0.1852	valid_1's binary_error: 0.3467
# [625]	training's binary_error: 0.18514	valid_1's binary_error: 0.34662
# [626]	training's binary_error: 0.18504	valid_1's binary_error: 0.34668
# [627]	training's binary_error: 0.18498	valid_1's binary_error: 0.34666
# [628]	training's binary_error: 0.18474	valid_1's binary_error: 0.34666
# [629]	training's binary_error: 0.18446	valid_1's binary_error: 0.34674
# [630]	training's binary_error: 0.18432	valid_1's binary_error: 0.34682
# [631]	training's binary_error: 0.18404	valid_1's binary_error: 0.34702
# [632]	training's binary_error: 0.1839	valid_1's binary_error: 0.34706
# [633]	training's binary_error: 0.18378	valid_1's binary_error: 0.34704
# [634]	training's binary_error: 0.18364	valid_1's binary_error: 0.34716
# [635]	training's binary_error: 0.18336	valid_1's binary_error: 0.3471
# [636]	training's binary_error: 0.18302	valid_1's binary_error: 0.3472
# [637]	training's binary_error: 0.183	valid_1's binary_error: 0.34728
# [638]	training's binary_error: 0.18302	valid_1's binary_error: 0.3472
# [639]	training's binary_error: 0.18278	valid_1's binary_error: 0.34706
# [640]	training's binary_error: 0.18258	valid_1's binary_error: 0.34712
# [641]	training's binary_error: 0.18256	valid_1's binary_error: 0.34712
# [642]	training's binary_error: 0.1824	valid_1's binary_error: 0.34708
# [643]	training's binary_error: 0.18204	valid_1's binary_error: 0.34718
# [644]	training's binary_error: 0.18196	valid_1's binary_error: 0.34714
# [645]	training's binary_error: 0.18174	valid_1's binary_error: 0.3472
# [646]	training's binary_error: 0.18144	valid_1's binary_error: 0.34714
# [647]	training's binary_error: 0.18136	valid_1's binary_error: 0.3473
# [648]	training's binary_error: 0.18134	valid_1's binary_error: 0.34738
# [649]	training's binary_error: 0.18112	valid_1's binary_error: 0.34738
# [650]	training's binary_error: 0.18092	valid_1's binary_error: 0.34718
# [651]	training's binary_error: 0.18076	valid_1's binary_error: 0.34734
# [652]	training's binary_error: 0.18066	valid_1's binary_error: 0.34728
# [653]	training's binary_error: 0.18038	valid_1's binary_error: 0.34728
# [654]	training's binary_error: 0.18022	valid_1's binary_error: 0.3473
# [655]	training's binary_error: 0.17992	valid_1's binary_error: 0.34742
# [656]	training's binary_error: 0.17964	valid_1's binary_error: 0.34756
# [657]	training's binary_error: 0.17942	valid_1's binary_error: 0.34736
# [658]	training's binary_error: 0.17936	valid_1's binary_error: 0.34738
# [659]	training's binary_error: 0.17934	valid_1's binary_error: 0.3475
# [660]	training's binary_error: 0.17924	valid_1's binary_error: 0.34758
# [661]	training's binary_error: 0.17908	valid_1's binary_error: 0.34738
# [662]	training's binary_error: 0.1791	valid_1's binary_error: 0.34738
# [663]	training's binary_error: 0.17896	valid_1's binary_error: 0.34758
# [664]	training's binary_error: 0.17886	valid_1's binary_error: 0.3477
# [665]	training's binary_error: 0.17872	valid_1's binary_error: 0.34778
# [666]	training's binary_error: 0.17854	valid_1's binary_error: 0.34786
# [667]	training's binary_error: 0.17828	valid_1's binary_error: 0.34784
# [668]	training's binary_error: 0.1781	valid_1's binary_error: 0.3479
# [669]	training's binary_error: 0.17786	valid_1's binary_error: 0.34788
# [670]	training's binary_error: 0.17764	valid_1's binary_error: 0.34786
# [671]	training's binary_error: 0.17746	valid_1's binary_error: 0.34798
# [672]	training's binary_error: 0.1772	valid_1's binary_error: 0.34818
# [673]	training's binary_error: 0.17702	valid_1's binary_error: 0.34812
# [674]	training's binary_error: 0.1768	valid_1's binary_error: 0.34824
# ...
# [1778]	training's binary_error: 0.06444	valid_1's binary_error: 0.35692
# [1779]	training's binary_error: 0.06444	valid_1's binary_error: 0.35694
# [1780]	training's binary_error: 0.06446	valid_1's binary_error: 0.35664
# [1781]	training's binary_error: 0.06442	valid_1's binary_error: 0.35684
# [1782]	training's binary_error: 0.06432	valid_1's binary_error: 0.35688
# [1783]	training's binary_error: 0.06426	valid_1's binary_error: 0.35686
# [1784]	training's binary_error: 0.06422	valid_1's binary_error: 0.35706
# [1785]	training's binary_error: 0.06414	valid_1's binary_error: 0.35706
# [1786]	training's binary_error: 0.06408	valid_1's binary_error: 0.35728
# [1787]	training's binary_error: 0.06398	valid_1's binary_error: 0.35722
# [1788]	training's binary_error: 0.06392	valid_1's binary_error: 0.35736
# [1789]	training's binary_error: 0.06378	valid_1's binary_error: 0.35744
# [1790]	training's binary_error: 0.06368	valid_1's binary_error: 0.35738
# [1791]	training's binary_error: 0.06356	valid_1's binary_error: 0.35762
# [1792]	training's binary_error: 0.06348	valid_1's binary_error: 0.35766
# [1793]	training's binary_error: 0.06352	valid_1's binary_error: 0.35762
# [1794]	training's binary_error: 0.06356	valid_1's binary_error: 0.3577
# [1795]	training's binary_error: 0.0635	valid_1's binary_error: 0.35766
# [1796]	training's binary_error: 0.06342	valid_1's binary_error: 0.35734
# [1797]	training's binary_error: 0.06334	valid_1's binary_error: 0.35728
# [1798]	training's binary_error: 0.06332	valid_1's binary_error: 0.3574
# [1799]	training's binary_error: 0.06312	valid_1's binary_error: 0.35716
# [1800]	training's binary_error: 0.0629	valid_1's binary_error: 0.35714
# [1801]	training's binary_error: 0.06278	valid_1's binary_error: 0.35716
# [1802]	training's binary_error: 0.06252	valid_1's binary_error: 0.35722
# [1803]	training's binary_error: 0.06238	valid_1's binary_error: 0.35722
# [1804]	training's binary_error: 0.06224	valid_1's binary_error: 0.35718
# [1805]	training's binary_error: 0.06206	valid_1's binary_error: 0.35726
# [1806]	training's binary_error: 0.062	valid_1's binary_error: 0.35734
# [1807]	training's binary_error: 0.06188	valid_1's binary_error: 0.35732
# [1808]	training's binary_error: 0.06182	valid_1's binary_error: 0.3573
# [1809]	training's binary_error: 0.06176	valid_1's binary_error: 0.35736
# [1810]	training's binary_error: 0.06178	valid_1's binary_error: 0.35738
# [1811]	training's binary_error: 0.06176	valid_1's binary_error: 0.35744
# [1812]	training's binary_error: 0.06164	valid_1's binary_error: 0.3575
# [1813]	training's binary_error: 0.06158	valid_1's binary_error: 0.35752
# [1814]	training's binary_error: 0.0616	valid_1's binary_error: 0.35734
# [1815]	training's binary_error: 0.06162	valid_1's binary_error: 0.3573
# [1816]	training's binary_error: 0.0615	valid_1's binary_error: 0.35734
# [1817]	training's binary_error: 0.06138	valid_1's binary_error: 0.35714
# [1818]	training's binary_error: 0.0613	valid_1's binary_error: 0.35714
# [1819]	training's binary_error: 0.06124	valid_1's binary_error: 0.3571
# [1820]	training's binary_error: 0.06122	valid_1's binary_error: 0.3571
# [1821]	training's binary_error: 0.06118	valid_1's binary_error: 0.35714
# [1822]	training's binary_error: 0.06102	valid_1's binary_error: 0.3572
# [1823]	training's binary_error: 0.06094	valid_1's binary_error: 0.35706
# [1824]	training's binary_error: 0.0609	valid_1's binary_error: 0.357
# [1825]	training's binary_error: 0.06084	valid_1's binary_error: 0.35696
# [1826]	training's binary_error: 0.06076	valid_1's binary_error: 0.35704
# [1827]	training's binary_error: 0.0607	valid_1's binary_error: 0.3571
# [1828]	training's binary_error: 0.06066	valid_1's binary_error: 0.35722
# [1829]	training's binary_error: 0.0606	valid_1's binary_error: 0.35712
# [1830]	training's binary_error: 0.06054	valid_1's binary_error: 0.35714
# [1831]	training's binary_error: 0.06046	valid_1's binary_error: 0.35728
# [1832]	training's binary_error: 0.06044	valid_1's binary_error: 0.35728
# [1833]	training's binary_error: 0.06042	valid_1's binary_error: 0.35728
# [1834]	training's binary_error: 0.06036	valid_1's binary_error: 0.3574
# [1835]	training's binary_error: 0.06034	valid_1's binary_error: 0.35736
# [1836]	training's binary_error: 0.0603	valid_1's binary_error: 0.35732
# [1837]	training's binary_error: 0.06028	valid_1's binary_error: 0.35728
# [1838]	training's binary_error: 0.06018	valid_1's binary_error: 0.35732
# [1839]	training's binary_error: 0.06008	valid_1's binary_error: 0.35726
# [1840]	training's binary_error: 0.05996	valid_1's binary_error: 0.35742
# [1841]	training's binary_error: 0.05982	valid_1's binary_error: 0.3574
# [1842]	training's binary_error: 0.05972	valid_1's binary_error: 0.3573
# [1843]	training's binary_error: 0.0597	valid_1's binary_error: 0.35728
# [1844]	training's binary_error: 0.05966	valid_1's binary_error: 0.35724
# [1845]	training's binary_error: 0.05964	valid_1's binary_error: 0.35724
# [1846]	training's binary_error: 0.05962	valid_1's binary_error: 0.3572
# [1847]	training's binary_error: 0.0596	valid_1's binary_error: 0.35712
# [1848]	training's binary_error: 0.05958	valid_1's binary_error: 0.35706
# [1849]	training's binary_error: 0.05952	valid_1's binary_error: 0.35702
# [1850]	training's binary_error: 0.05954	valid_1's binary_error: 0.35704
# [1851]	training's binary_error: 0.05952	valid_1's binary_error: 0.35718
# [1852]	training's binary_error: 0.0595	valid_1's binary_error: 0.35722
# [1853]	training's binary_error: 0.0594	valid_1's binary_error: 0.35742
# [1854]	training's binary_error: 0.05936	valid_1's binary_error: 0.35754
# [1855]	training's binary_error: 0.05934	valid_1's binary_error: 0.3575
# [1856]	training's binary_error: 0.05938	valid_1's binary_error: 0.3575
# [1857]	training's binary_error: 0.05938	valid_1's binary_error: 0.35736
# [1858]	training's binary_error: 0.05938	valid_1's binary_error: 0.35744
# [1859]	training's binary_error: 0.05936	valid_1's binary_error: 0.35734
# [1860]	training's binary_error: 0.05934	valid_1's binary_error: 0.35738
# [1861]	training's binary_error: 0.05932	valid_1's binary_error: 0.3574
# [1862]	training's binary_error: 0.05932	valid_1's binary_error: 0.35732
# [1863]	training's binary_error: 0.05928	valid_1's binary_error: 0.35734
# [1864]	training's binary_error: 0.05934	valid_1's binary_error: 0.35734
# [1865]	training's binary_error: 0.05912	valid_1's binary_error: 0.3574
# [1866]	training's binary_error: 0.05908	valid_1's binary_error: 0.3574
# [1867]	training's binary_error: 0.05896	valid_1's binary_error: 0.35748
# [1868]	training's binary_error: 0.05896	valid_1's binary_error: 0.35744
# [1869]	training's binary_error: 0.05894	valid_1's binary_error: 0.35736
# [1870]	training's binary_error: 0.05886	valid_1's binary_error: 0.35726
# [1871]	training's binary_error: 0.05884	valid_1's binary_error: 0.35722
# [1872]	training's binary_error: 0.05884	valid_1's binary_error: 0.3572
# [1873]	training's binary_error: 0.05882	valid_1's binary_error: 0.35726
# [1874]	training's binary_error: 0.05866	valid_1's binary_error: 0.35722
# [1875]	training's binary_error: 0.05864	valid_1's binary_error: 0.35726
# [1876]	training's binary_error: 0.05862	valid_1's binary_error: 0.3573
# [1877]	training's binary_error: 0.05842	valid_1's binary_error: 0.3573
# [1878]	training's binary_error: 0.0583	valid_1's binary_error: 0.35726
# [1879]	training's binary_error: 0.05816	valid_1's binary_error: 0.35714
# [1880]	training's binary_error: 0.05816	valid_1's binary_error: 0.35714
# [1881]	training's binary_error: 0.05808	valid_1's binary_error: 0.3572
# [1882]	training's binary_error: 0.05806	valid_1's binary_error: 0.35726
# [1883]	training's binary_error: 0.05806	valid_1's binary_error: 0.35728
# [1884]	training's binary_error: 0.05806	valid_1's binary_error: 0.35734
# [1885]	training's binary_error: 0.05804	valid_1's binary_error: 0.35734
# [1886]	training's binary_error: 0.05796	valid_1's binary_error: 0.3573
# [1887]	training's binary_error: 0.05794	valid_1's binary_error: 0.35738
# [1888]	training's binary_error: 0.05794	valid_1's binary_error: 0.35746
# [1889]	training's binary_error: 0.05788	valid_1's binary_error: 0.35746
# [1890]	training's binary_error: 0.0578	valid_1's binary_error: 0.35758
# [1891]	training's binary_error: 0.05768	valid_1's binary_error: 0.35762
# [1892]	training's binary_error: 0.05764	valid_1's binary_error: 0.3576
# [1893]	training's binary_error: 0.05754	valid_1's binary_error: 0.35768
# [1894]	training's binary_error: 0.05756	valid_1's binary_error: 0.35776
# [1895]	training's binary_error: 0.05754	valid_1's binary_error: 0.35776
# [1896]	training's binary_error: 0.05744	valid_1's binary_error: 0.35766
# [1897]	training's binary_error: 0.05732	valid_1's binary_error: 0.35768
# [1898]	training's binary_error: 0.05714	valid_1's binary_error: 0.35776
# [1899]	training's binary_error: 0.05716	valid_1's binary_error: 0.35786
# [1900]	training's binary_error: 0.05714	valid_1's binary_error: 0.35788
# [1901]	training's binary_error: 0.05714	valid_1's binary_error: 0.35794
# [1902]	training's binary_error: 0.05712	valid_1's binary_error: 0.35804
# [1903]	training's binary_error: 0.05714	valid_1's binary_error: 0.3582
# [1904]	training's binary_error: 0.05712	valid_1's binary_error: 0.35846
# [1905]	training's binary_error: 0.05704	valid_1's binary_error: 0.35832
# [1906]	training's binary_error: 0.05704	valid_1's binary_error: 0.3583
# [1907]	training's binary_error: 0.057	valid_1's binary_error: 0.35816
# [1908]	training's binary_error: 0.05706	valid_1's binary_error: 0.35802
# [1909]	training's binary_error: 0.05702	valid_1's binary_error: 0.358
# [1910]	training's binary_error: 0.05702	valid_1's binary_error: 0.35798
# [1911]	training's binary_error: 0.05696	valid_1's binary_error: 0.35794
# [1912]	training's binary_error: 0.0569	valid_1's binary_error: 0.358
# [1913]	training's binary_error: 0.05684	valid_1's binary_error: 0.35788
# [1914]	training's binary_error: 0.0568	valid_1's binary_error: 0.35786
# [1915]	training's binary_error: 0.05678	valid_1's binary_error: 0.3579
# [1916]	training's binary_error: 0.05674	valid_1's binary_error: 0.3579
# [1917]	training's binary_error: 0.05664	valid_1's binary_error: 0.35776
# [1918]	training's binary_error: 0.05666	valid_1's binary_error: 0.35778
# [1919]	training's binary_error: 0.05666	valid_1's binary_error: 0.35776
# [1920]	training's binary_error: 0.05662	valid_1's binary_error: 0.35774
# [1921]	training's binary_error: 0.05646	valid_1's binary_error: 0.35776
# [1922]	training's binary_error: 0.05642	valid_1's binary_error: 0.3579
# [1923]	training's binary_error: 0.05638	valid_1's binary_error: 0.35784
# [1924]	training's binary_error: 0.05626	valid_1's binary_error: 0.358
# [1925]	training's binary_error: 0.0562	valid_1's binary_error: 0.35802
# [1926]	training's binary_error: 0.05614	valid_1's binary_error: 0.3579
# [1927]	training's binary_error: 0.05608	valid_1's binary_error: 0.35788
# [1928]	training's binary_error: 0.05592	valid_1's binary_error: 0.35798
# [1929]	training's binary_error: 0.0559	valid_1's binary_error: 0.35802
# [1930]	training's binary_error: 0.05582	valid_1's binary_error: 0.35794
# [1931]	training's binary_error: 0.05576	valid_1's binary_error: 0.358
# [1932]	training's binary_error: 0.05572	valid_1's binary_error: 0.35796
# [1933]	training's binary_error: 0.0557	valid_1's binary_error: 0.35786
# [1934]	training's binary_error: 0.05568	valid_1's binary_error: 0.35786
# [1935]	training's binary_error: 0.0557	valid_1's binary_error: 0.35794
# [1936]	training's binary_error: 0.05568	valid_1's binary_error: 0.35776
# [1937]	training's binary_error: 0.0556	valid_1's binary_error: 0.35762
# [1938]	training's binary_error: 0.05556	valid_1's binary_error: 0.3576
# [1939]	training's binary_error: 0.05552	valid_1's binary_error: 0.35772
# [1940]	training's binary_error: 0.05552	valid_1's binary_error: 0.35782
# [1941]	training's binary_error: 0.0555	valid_1's binary_error: 0.3579
# [1942]	training's binary_error: 0.05546	valid_1's binary_error: 0.35778
# [1943]	training's binary_error: 0.0554	valid_1's binary_error: 0.35782
# [1944]	training's binary_error: 0.05534	valid_1's binary_error: 0.35786
# [1945]	training's binary_error: 0.05534	valid_1's binary_error: 0.35786
# [1946]	training's binary_error: 0.0553	valid_1's binary_error: 0.35778
# [1947]	training's binary_error: 0.0553	valid_1's binary_error: 0.35768
# [1948]	training's binary_error: 0.05526	valid_1's binary_error: 0.35764
# [1949]	training's binary_error: 0.05522	valid_1's binary_error: 0.3576
# [1950]	training's binary_error: 0.05492	valid_1's binary_error: 0.35762
# [1951]	training's binary_error: 0.05484	valid_1's binary_error: 0.35776
# [1952]	training's binary_error: 0.0547	valid_1's binary_error: 0.35774
# [1953]	training's binary_error: 0.05466	valid_1's binary_error: 0.35766
# [1954]	training's binary_error: 0.05458	valid_1's binary_error: 0.35774
# [1955]	training's binary_error: 0.05452	valid_1's binary_error: 0.35766
# [1956]	training's binary_error: 0.05434	valid_1's binary_error: 0.3577
# [1957]	training's binary_error: 0.05418	valid_1's binary_error: 0.35768
# [1958]	training's binary_error: 0.05426	valid_1's binary_error: 0.3578
# [1959]	training's binary_error: 0.0542	valid_1's binary_error: 0.35774
# [1960]	training's binary_error: 0.05414	valid_1's binary_error: 0.35778
# [1961]	training's binary_error: 0.05414	valid_1's binary_error: 0.3578
# [1962]	training's binary_error: 0.05404	valid_1's binary_error: 0.3578
# [1963]	training's binary_error: 0.05396	valid_1's binary_error: 0.35788
# [1964]	training's binary_error: 0.05388	valid_1's binary_error: 0.35792
# [1965]	training's binary_error: 0.05386	valid_1's binary_error: 0.35796
# [1966]	training's binary_error: 0.0538	valid_1's binary_error: 0.35804
# [1967]	training's binary_error: 0.05374	valid_1's binary_error: 0.358
# [1968]	training's binary_error: 0.05374	valid_1's binary_error: 0.35796
# [1969]	training's binary_error: 0.05362	valid_1's binary_error: 0.35798
# [1970]	training's binary_error: 0.05356	valid_1's binary_error: 0.35782
# [1971]	training's binary_error: 0.05352	valid_1's binary_error: 0.35782
# [1972]	training's binary_error: 0.05342	valid_1's binary_error: 0.35758
# [1973]	training's binary_error: 0.05344	valid_1's binary_error: 0.35766
# [1974]	training's binary_error: 0.05338	valid_1's binary_error: 0.3576
# [1975]	training's binary_error: 0.0534	valid_1's binary_error: 0.35768
# [1976]	training's binary_error: 0.0534	valid_1's binary_error: 0.3578
# [1977]	training's binary_error: 0.05332	valid_1's binary_error: 0.35792
# [1978]	training's binary_error: 0.0533	valid_1's binary_error: 0.35794
# [1979]	training's binary_error: 0.0533	valid_1's binary_error: 0.35784
# [1980]	training's binary_error: 0.05328	valid_1's binary_error: 0.35786
# [1981]	training's binary_error: 0.05326	valid_1's binary_error: 0.35778
# [1982]	training's binary_error: 0.05326	valid_1's binary_error: 0.35766
# [1983]	training's binary_error: 0.05324	valid_1's binary_error: 0.35768
# [1984]	training's binary_error: 0.05314	valid_1's binary_error: 0.35774
# [1985]	training's binary_error: 0.05302	valid_1's binary_error: 0.35766
# [1986]	training's binary_error: 0.05302	valid_1's binary_error: 0.3577
# [1987]	training's binary_error: 0.053	valid_1's binary_error: 0.3577
# [1988]	training's binary_error: 0.05298	valid_1's binary_error: 0.35784
# [1989]	training's binary_error: 0.0529	valid_1's binary_error: 0.35782
# [1990]	training's binary_error: 0.05288	valid_1's binary_error: 0.35784
# [1991]	training's binary_error: 0.05284	valid_1's binary_error: 0.35774
# [1992]	training's binary_error: 0.05272	valid_1's binary_error: 0.35764
# [1993]	training's binary_error: 0.05262	valid_1's binary_error: 0.35774
# [1994]	training's binary_error: 0.05256	valid_1's binary_error: 0.35766
# [1995]	training's binary_error: 0.05248	valid_1's binary_error: 0.35762
# [1996]	training's binary_error: 0.05248	valid_1's binary_error: 0.35764
# [1997]	training's binary_error: 0.05246	valid_1's binary_error: 0.35774
# [1998]	training's binary_error: 0.05242	valid_1's binary_error: 0.35782
# [1999]	training's binary_error: 0.05228	valid_1's binary_error: 0.3577
# [2000]	training's binary_error: 0.05212	valid_1's binary_error: 0.35768

# %% [markdown]
# ## A Wrapper

# %%
import io
import multiprocessing
from contextlib import redirect_stdout
from copy import deepcopy
from dataclasses import dataclass, asdict
import hyperopt.pyll
from hyperopt import fmin, tpe, hp
import numpy as np
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
import torch

import copy
cpu_count = 4
use_gpu = False
@dataclass
class LGBOpt:
    num_threads: any = hp.choice('num_threads', [cpu_count])
    num_leaves: any = hp.choice('num_leaves', [64])
    metric: any = hp.choice('metric', ['binary_error'])
    num_round: any = hp.choice('num_rounds', [1000])
    objective: any = hp.choice('objective', ['binary'])
    learning_rate: any = hp.uniform('learning_rate', 0.01, 0.1)
    feature_fraction: any = hp.uniform('feature_fraction', 0.5, 1.0)
    bagging_fraction: any = hp.uniform('bagging_fraction', 0.8, 1.0)
    device_type: any = hp.choice('device_tpye', ['gpu']) if use_gpu else hp.choice('device_type',
                                                                                   ['cpu'])
    boosting: any = hp.choice('boosting', ['gbdt', 'dart', 'goss'])
    extra_trees: any = hp.choice('extra_tress', [False, True])
    drop_rate: any = hp.uniform('drop_rate', 0, 0.2)
    uniform_drop: any = hp.choice('uniform_drop', [True, False])
    lambda_l1: any = hp.uniform('lambda_l1', 0, 10)  # TODO: Check range
    lambda_l2: any = hp.uniform('lambda_l2', 0, 10)  # TODO: Check range
    min_gain_to_split: any = hp.uniform('min_gain_to_split', 0, 1)  # TODO: Check range
    min_data_in_bin = hp.choice('min_data_in_bin', [3, 5, 10, 15, 20, 50])

    @staticmethod
    def get_common_params():
        return {'num_thread': 4, 'num_leaves': 12, 'metric': 'binary', 'objective': 'binary',
                'num_round': 1000, 'learning_rate': 0.01, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}

# %%
class FitterBase(object):
    def __init__(self, label, metric, max_eval=100, opt=None):
        self.label = label
        self.metric = metric
        self.opt_params = dict()
        self.max_eval = max_eval
        self.opt = opt

    def get_loss(self, y, y_pred):
        if self.metric == 'error':
            return 1 - accuracy_score(y, y_pred)
        elif self.metric == 'precision':
            return 1 - precision_score(y, y_pred)
        elif self.metric == 'recall':
            return 1 - recall_score(y, y_pred)
        elif self.metric == 'macro_f1':
            return 1 - f1_score(y, y_pred, average='macro')
        elif self.metric == 'micro_f1':
            return 1 - f1_score(y, y_pred, average='micro')
        elif self.metric == 'auc':  # TODO: Add a warning checking if y_predict is all [0, 1], it should be probability
            return 1 - roc_auc_score(y, y_pred)
        else:
            raise Exception("Not implemented yet.")

# %%
class LGBFitter(FitterBase):
    def __init__(self, label='label', metric='error', opt: LGBOpt = None, max_eval=100):
        super(LGBFitter, self).__init__(label, metric, max_eval)
        if opt is not None:
            self.opt = opt
        else:
            self.opt = LGBOpt()
        self.best_round = None
        self.clf = None

    def train(self, train_df, eval_df, params=None, use_best_eval=True):
        self.best_round = None
        dtrain = lgb.Dataset(train_df.drop(columns=[self.label]), train_df[self.label])
        deval = lgb.Dataset(eval_df.drop(columns=[self.label]), eval_df[self.label])
        evallist = [dtrain, deval]
        if params is None:
            use_params = deepcopy(self.opt_params)
        else:
            use_params = deepcopy(params)

        num_round = use_params.pop('num_round')
        if use_best_eval:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
                output = buf.getvalue().split("\n")
            min_error = np.inf
            min_index = 0
            for idx in range(len(output) - 1):
                if len(output[idx].split("\t")) == 3:
                    temp = float(output[idx].split("\t")[2].split(":")[1])
                    if min_error > temp:
                        min_error = temp
                        min_index = int(output[idx].split("\t")[0][1:-1])
            print("The minimum is attained in round %d" % (min_index + 1))
            self.best_round = min_index + 1
            return output
        else:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
                output = buf.getvalue().split("\n")
            self.best_round = num_round
            return output

    def search(self, train_df, eval_df, use_best_eval=True):
        self.opt_params = dict()

        def train_impl(params):
            self.train(train_df, eval_df, params, use_best_eval)
            if self.metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           num_iteration=self.best_round) > 0.5).astype(int)
            return self.get_loss(eval_df[self.label], y_pred)

        self.opt_params = fmin(train_impl, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def search_k_fold(self, k_fold, data, use_best_eval=True):
        self.opt_params = dict()

        def train_impl_nfold(params):
            loss = list()
            for train_id, eval_id in k_fold.split(data):
                train_df = data.loc[train_id]
                eval_df = data.loc[eval_id]
                self.train(train_df, eval_df, params, use_best_eval)
                if self.metric == 'auc':
                    y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
                else:
                    y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                               num_iteration=self.best_round) > 0.5).astype(int)
                loss.append(self.get_loss(eval_df[self.label], y_pred))
            return np.mean(loss)

        self.opt_params = fmin(train_impl_nfold, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def train_k_fold(self, k_fold, train_data, test_data, params=None, drop_test_y=True, use_best_eval=True):
        acc_result = list()
        train_pred = np.empty(train_data.shape[0])
        test_pred = np.empty(test_data.shape[0])
        if drop_test_y:
            dtest = test_data.drop(columns=self.label)
        else:
            dtest = test_data

        models = list()
        for train_id, eval_id in k_fold.split(train_data):
            train_df = train_data.loc[train_id]
            eval_df = train_data.loc[eval_id]
            self.train(train_df, eval_df, params, use_best_eval)
            models.append(copy.deepcopy(self.clf))
            train_pred[eval_id] = self.clf.predict(eval_df.drop(columns=self.label), num_iteration=self.best_round)
            if self.metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           num_iteration=self.best_round) > 0.5).astype(int)
            acc_result.append(self.get_loss(eval_df[self.label], y_pred))
            test_pred += self.clf.predict(dtest, num_iteration=self.best_round)
        test_pred /= k_fold.n_splits
        return train_pred, test_pred, acc_result, models

# %%
fitter = LGBFitter(label='loan_status')

# %%
params = {'num_thread': 4, 'num_leaves': 12, 'metric': 'binary', 'objective': 'binary',
                'num_round': 2000, 'learning_rate': 0.02, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5)

# %%
fitter.train_k_fold(kfold, train, test, params = params)
# Out:
# The minimum is attained in round 752
# Finished loading model, total used 2000 iterations
# The minimum is attained in round 1128
# Finished loading model, total used 2000 iterations
# The minimum is attained in round 1255
# Finished loading model, total used 2000 iterations
# The minimum is attained in round 746
# Finished loading model, total used 2000 iterations
# The minimum is attained in round 1012
# Finished loading model, total used 2000 iterations
# (array([0.66544515, 0.63186229, 0.34167458, ..., 0.61421409, 0.52737908,
#         0.10582775]),
#  array([0.32797432, 0.36489331, 0.27675128, ..., 0.32066783, 0.31667225,
#         0.41526439]),
#  [0.43300000000000005, 0.4312, 0.4272, 0.4302, 0.42290000000000005],
#  [<lightgbm.basic.Booster at 0x18a46662a48>,
#   <lightgbm.basic.Booster at 0x18a46d24488>,
#   <lightgbm.basic.Booster at 0x18a484f2a88>,
#   <lightgbm.basic.Booster at 0x18a4642b988>,
#   <lightgbm.basic.Booster at 0x18a461f3508>])

# %%
train1=train.copy()
train1['continuous_inc_funded_ratio']=train1['continuous_annual_inc']/train1['continuous_funded_amnt']
test1=test.copy()
test1['continuous_inc_funded_ratio']=test1['continuous_annual_inc']/test1['continuous_funded_amnt']

# %%
fitter.train_k_fold(kfold, train1, test1, params = params)
# Out:
# The minimum is attained in round 788
# Finished loading model, total used 2000 iterations
# The minimum is attained in round 875
# Finished loading model, total used 2000 iterations
# The minimum is attained in round 1330
# Finished loading model, total used 2000 iterations
# The minimum is attained in round 1138
# Finished loading model, total used 2000 iterations
# The minimum is attained in round 837
# Finished loading model, total used 2000 iterations
# (array([0.64132968, 0.59716021, 0.35742535, ..., 0.59169384, 0.52140829,
#         0.14728204]),
#  array([0.30160404, 0.39559409, 0.26574056, ..., 0.32128021, 0.30451696,
#         0.4011293 ]),
#  [0.43279999999999996, 0.4302, 0.42589999999999995, 0.4286, 0.4226],
#  [<lightgbm.basic.Booster at 0x18a00aa5148>,
#   <lightgbm.basic.Booster at 0x18a37af4208>,
#   <lightgbm.basic.Booster at 0x18a3affea48>,
#   <lightgbm.basic.Booster at 0x18a00aa5488>,
#   <lightgbm.basic.Booster at 0x18a484d6a08>])
